# %% [markdown]
# # Introduction to Machine Learning Coursework (Group 11)
# ## Part 1 : Minimizing Three-Hump-Camel (THC) function

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %%
# Change working directory; Necessary when importing gredient descent module
#os.chdir('PUT YOUR WORKING DIRECTORY IN HERE')
os.chdir('/Users/congcondk/Desktop/CASS/Term3/Machine Learning/Coursework/Output')

# %%
# Defining THC function and it's gradient
def Three_Hump_Camel(x):
    x1, x2 = x
    return 2*(x1**2) - 1.05*(x1**4) + (x1**6)/6 + (x1*x2) + (x2**2)

def Three_Hump_Camel_gradient(x):
    x1,x2=x
    f1 = 4*x1 - 4.2*(x1**3) + (x1**5) + x2
    f2 = x1 + 2*x2
    return np.array([f1,f2])

# %%
# The graph of THC function

x1 = np.linspace(-2,2,100)
x2 = np.linspace(-2,2,100)
x1grid, x2grid = np.meshgrid(x1, x2)
xx = np.stack([x1grid, x2grid])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x1grid, x2grid, Three_Hump_Camel(xx),cmap=cm.gist_rainbow)
ax.set_title('Three-Hump Camel function')
ax.set_xlabel('x1')
ax.set_ylabel('x2')

plt.show()

# %%
# Importing the gradient descent (2-D) module
from gd_2d import gd_2d_plain, gd_2d_momentum, gd_2d_NAG

# Initial Value
x0 = [2,2]

# %%
# Plain vanilla method
object1 = gd_2d_plain(Three_Hump_Camel,Three_Hump_Camel_gradient)
res1 = object1.minimize(x0,0.001,tol=1e-8)
print('function value of plain method : ',np.around(res1.fval,4))

plt.plot(np.arange(res1.niter+1),np.log(res1.fval_path))
plt.xlabel('Iteration number')
plt.ylabel('Function value\n(log scale)')
plt.title('Path of function values')
plt.show()
# Out:
# Optimization terminated successfully
# function value of plain method :  0.2986

# %%
# Momentum method
object2 = gd_2d_momentum(Three_Hump_Camel,Three_Hump_Camel_gradient)
res2 = object2.minimize(x0,0.001,tol=1e-8)
print('function value of the momentum method : ',np.around(res2.fval,4))
plt.plot(np.arange(res2.niter+1),np.log(res2.fval_path))
plt.xlabel('Iteration number')
plt.ylabel('Function value\n(log scale)')
plt.title('Path of function values')
plt.show()
# Out:
# Optimization terminated successfully
# function value of the momentum method :  0.0

# %%
# NAG method
object3 = gd_2d_NAG(Three_Hump_Camel,Three_Hump_Camel_gradient)
res3 = object3.minimize(x0,0.001,tol=1e-8)
print('function value of NAG method : ',np.around(res3.fval,4))

plt.plot(np.arange(res3.niter+1),np.log(res3.fval_path))
plt.xlabel('Iteration number')
plt.ylabel('Function value\n(log scale)')
plt.title('Path of function values')
plt.show()
# Out:
# Optimization terminated successfully
# function value of NAG method :  0.0
